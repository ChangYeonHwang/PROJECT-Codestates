# %% [markdown]
# <a href="https://colab.research.google.com/github/Drunkendonut/PROJECT-Codestates/blob/main/NFL_%EA%B2%8C%EC%9E%84_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip uninstall pandas-profiling
! pip install pandas-profiling

# %%
pip install sportsreference

# %%
from sportsreference.nfl.boxscore import Boxscores, Boxscore
import pandas as pd
import numpy as np

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d953ba5f-6b73-4fe8-bc3c-a70a827a74e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d953ba5f-6b73-4fe8-bc3c-a70a827a74e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nfl_elo_latest.csv to nfl_elo_latest.csv

# %%
def game_data(game_df,game_stats):
    try:
        away_team_df = game_df[['away_name', 'away_abbr', 'away_score']].rename(columns = {'away_name': 'team_name', 'away_abbr': 'team_abbr', 'away_score': 'score'})
        home_team_df = game_df[['home_name','home_abbr', 'home_score']].rename(columns = {'home_name': 'team_name', 'home_abbr': 'team_abbr', 'home_score': 'score'})
        try:
            if game_df.loc[0,'away_score'] > game_df.loc[0,'home_score']:
                away_team_df = pd.merge(away_team_df, pd.DataFrame({'game_won' : [1], 'game_lost' : [0]}),left_index = True, right_index = True)
                home_team_df = pd.merge(home_team_df, pd.DataFrame({'game_won' : [0], 'game_lost' : [1]}),left_index = True, right_index = True)
            elif game_df.loc[0,'away_score'] < game_df.loc[0,'home_score']:
                away_team_df = pd.merge(away_team_df, pd.DataFrame({'game_won' : [0], 'game_lost' : [1]}),left_index = True, right_index = True)
                home_team_df = pd.merge(home_team_df, pd.DataFrame({'game_won' : [1], 'game_lost' : [0]}),left_index = True, right_index = True)
            else: 
                away_team_df = pd.merge(away_team_df, pd.DataFrame({'game_won' : [0], 'game_lost' : [0]}),left_index = True, right_index = True)
                home_team_df = pd.merge(home_team_df, pd.DataFrame({'game_won' : [0], 'game_lost' : [0]}),left_index = True, right_index = True)
        except TypeError:
                away_team_df = pd.merge(away_team_df, pd.DataFrame({'game_won' : [np.nan], 'game_lost' : [np.nan]}),left_index = True, right_index = True)
                home_team_df = pd.merge(home_team_df, pd.DataFrame({'game_won' : [np.nan], 'game_lost' : [np.nan]}),left_index = True, right_index = True)        

        away_stats_df = game_stats.dataframe[['away_first_downs', 'away_fourth_down_attempts',
               'away_fourth_down_conversions', 'away_fumbles', 'away_fumbles_lost',
               'away_interceptions', 'away_net_pass_yards', 'away_pass_attempts',
               'away_pass_completions', 'away_pass_touchdowns', 'away_pass_yards',
               'away_penalties', 'away_points', 'away_rush_attempts',
               'away_rush_touchdowns', 'away_rush_yards', 'away_third_down_attempts',
               'away_third_down_conversions', 'away_time_of_possession',
               'away_times_sacked', 'away_total_yards', 'away_turnovers',
               'away_yards_from_penalties', 'away_yards_lost_from_sacks']].reset_index().drop(columns ='index').rename(columns = {
               'away_first_downs': 'first_downs', 'away_fourth_down_attempts':'fourth_down_attempts',
               'away_fourth_down_conversions':'fourth_down_conversions' , 'away_fumbles': 'fumbles', 'away_fumbles_lost': 'fumbles_lost',
               'away_interceptions': 'interceptions', 'away_net_pass_yards':'net_pass_yards' , 'away_pass_attempts': 'pass_attempts',
               'away_pass_completions':'pass_completions' , 'away_pass_touchdowns': 'pass_touchdowns', 'away_pass_yards': 'pass_yards',
               'away_penalties': 'penalties', 'away_points': 'points', 'away_rush_attempts': 'rush_attempts',
               'away_rush_touchdowns': 'rush_touchdowns', 'away_rush_yards': 'rush_yards', 'away_third_down_attempts': 'third_down_attempts',
               'away_third_down_conversions': 'third_down_conversions', 'away_time_of_possession': 'time_of_possession',
               'away_times_sacked': 'times_sacked', 'away_total_yards': 'total_yards', 'away_turnovers': 'turnovers',
               'away_yards_from_penalties':'yards_from_penalties', 'away_yards_lost_from_sacks': 'yards_lost_from_sacks'})

        home_stats_df = game_stats.dataframe[['home_first_downs', 'home_fourth_down_attempts',
               'home_fourth_down_conversions', 'home_fumbles', 'home_fumbles_lost',
               'home_interceptions', 'home_net_pass_yards', 'home_pass_attempts',
               'home_pass_completions', 'home_pass_touchdowns', 'home_pass_yards',
               'home_penalties', 'home_points', 'home_rush_attempts',
               'home_rush_touchdowns', 'home_rush_yards', 'home_third_down_attempts',
               'home_third_down_conversions', 'home_time_of_possession',
               'home_times_sacked', 'home_total_yards', 'home_turnovers',
               'home_yards_from_penalties', 'home_yards_lost_from_sacks']].reset_index().drop(columns = 'index').rename(columns = {
               'home_first_downs': 'first_downs', 'home_fourth_down_attempts':'fourth_down_attempts',
               'home_fourth_down_conversions':'fourth_down_conversions' , 'home_fumbles': 'fumbles', 'home_fumbles_lost': 'fumbles_lost',
               'home_interceptions': 'interceptions', 'home_net_pass_yards':'net_pass_yards' , 'home_pass_attempts': 'pass_attempts',
               'home_pass_completions':'pass_completions' , 'home_pass_touchdowns': 'pass_touchdowns', 'home_pass_yards': 'pass_yards',
               'home_penalties': 'penalties', 'home_points': 'points', 'home_rush_attempts': 'rush_attempts',
               'home_rush_touchdowns': 'rush_touchdowns', 'home_rush_yards': 'rush_yards', 'home_third_down_attempts': 'third_down_attempts',
               'home_third_down_conversions': 'third_down_conversions', 'home_time_of_possession': 'time_of_possession',
               'home_times_sacked': 'times_sacked', 'home_total_yards': 'total_yards', 'home_turnovers': 'turnovers',
               'home_yards_from_penalties':'yards_from_penalties', 'home_yards_lost_from_sacks': 'yards_lost_from_sacks'})

        away_team_df = pd.merge(away_team_df, away_stats_df,left_index = True, right_index = True)
        home_team_df = pd.merge(home_team_df, home_stats_df,left_index = True, right_index = True)
        try:
            away_team_df['time_of_possession'] = (int(away_team_df['time_of_possession'].loc[0][0:2]) * 60) + int(away_team_df['time_of_possession'].loc[0][3:5])
            home_team_df['time_of_possession'] = (int(home_team_df['time_of_possession'].loc[0][0:2]) * 60) + int(home_team_df['time_of_possession'].loc[0][3:5])
        except TypeError:
            away_team_df['time_of_possession'] = np.nan
            home_team_df['time_of_possession'] = np.nan
    except TypeError:
        away_team_df = pd.DataFrame()
        home_team_df = pd.DataFrame()
    return away_team_df, home_team_df


def game_data_up_to_week(weeks,year):
    weeks_games_df = pd.DataFrame()
    for w in range(len(weeks)):
        date_string = str(weeks[w]) + '-' + str(year)
        week_scores = Boxscores(weeks[w],year)
        week_games_df = pd.DataFrame()
        for g in range(len(week_scores.games[date_string])):
            game_str = week_scores.games[date_string][g]['boxscore']
            game_stats = Boxscore(game_str)
            game_df = pd.DataFrame(week_scores.games[date_string][g], index = [0])
            away_team_df, home_team_df = game_data(game_df,game_stats)
            away_team_df['week'] = weeks[w]
            home_team_df['week'] = weeks[w]
            week_games_df = pd.concat([week_games_df,away_team_df])
            week_games_df = pd.concat([week_games_df,home_team_df])
        weeks_games_df = pd.concat([weeks_games_df,week_games_df])
    return weeks_games_df

def get_schedule(year):
    weeks = list(range(1,18))
    schedule_df = pd.DataFrame()
    for w in range(len(weeks)):
        date_string = str(weeks[w]) + '-' + str(year)
        week_scores = Boxscores(weeks[w],year)
        week_games_df = pd.DataFrame()
        for g in range(len(week_scores.games[date_string])):
            game = pd.DataFrame(week_scores.games[date_string][g], index = [0])[['away_name', 'away_abbr','home_name', 'home_abbr','winning_name', 'winning_abbr' ]]
            game['week'] = weeks[w]
            week_games_df = pd.concat([week_games_df,game])
        schedule_df = pd.concat([schedule_df, week_games_df]).reset_index().drop(columns = 'index') 
    return schedule_df 

def agg_weekly_data(schedule_df,weeks_games_df,current_week,weeks):
    schedule_df = schedule_df[schedule_df.week < current_week]
    agg_games_df = pd.DataFrame()
    for w in range(1,len(weeks)):
        games_df = schedule_df[schedule_df.week == weeks[w]]
        agg_weekly_df = weeks_games_df[weeks_games_df.week < weeks[w]].drop(columns = ['score','week','game_won', 'game_lost']).groupby(by=["team_name", "team_abbr"]).mean().reset_index()
        win_loss_df = weeks_games_df[weeks_games_df.week < weeks[w]][["team_name", "team_abbr",'game_won', 'game_lost']].groupby(by=["team_name", "team_abbr"]).sum().reset_index()
        win_loss_df['win_perc'] = win_loss_df['game_won'] / (win_loss_df['game_won'] + win_loss_df['game_lost'])
        win_loss_df = win_loss_df.drop(columns = ['game_won', 'game_lost'])

        try:
            agg_weekly_df['fourth_down_perc'] = agg_weekly_df['fourth_down_conversions'] / agg_weekly_df['fourth_down_attempts']  
        except ZeroDivisionError:
            agg_weekly_df['fourth_down_perc'] = 0 
        agg_weekly_df['fourth_down_perc'] = agg_weekly_df['fourth_down_perc'].fillna(0)

        try:
            agg_weekly_df['third_down_perc'] = agg_weekly_df['third_down_conversions'] / agg_weekly_df['third_down_attempts']  
        except ZeroDivisionError:
            agg_weekly_df['third_down_perc'] = 0
        agg_weekly_df['third_down_perc'] = agg_weekly_df['third_down_perc'].fillna(0)  

        agg_weekly_df = agg_weekly_df.drop(columns = ['fourth_down_attempts', 'fourth_down_conversions', 'third_down_attempts', 'third_down_conversions'])
        agg_weekly_df = pd.merge(win_loss_df,agg_weekly_df,left_on = ['team_name', 'team_abbr'], right_on = ['team_name', 'team_abbr'])

        away_df = pd.merge(games_df,agg_weekly_df,how = 'inner', left_on = ['away_name', 'away_abbr'], right_on = ['team_name', 'team_abbr']).drop(columns = ['team_name', 'team_abbr']).rename(columns = {
                'win_perc': 'away_win_perc',
               'first_downs': 'away_first_downs', 'fumbles': 'away_fumbles', 'fumbles_lost':'away_fumbles_lost', 'interceptions':'away_interceptions',
               'net_pass_yards': 'away_net_pass_yards', 'pass_attempts':'away_pass_attempts', 'pass_completions':'away_pass_completions',
               'pass_touchdowns':'away_pass_touchdowns', 'pass_yards':'away_pass_yards', 'penalties':'away_penalties', 'points':'away_points', 'rush_attempts':'away_rush_attempts',
               'rush_touchdowns':'away_rush_touchdowns', 'rush_yards':'away_rush_yards', 'time_of_possession':'away_time_of_possession', 'times_sacked':'away_times_sacked',
               'total_yards':'away_total_yards', 'turnovers':'away_turnovers', 'yards_from_penalties':'away_yards_from_penalties',
               'yards_lost_from_sacks': 'away_yards_lost_from_sacks', 'fourth_down_perc':'away_fourth_down_perc', 'third_down_perc':'away_third_down_perc'})

        home_df = pd.merge(games_df,agg_weekly_df,how = 'inner', left_on = ['home_name', 'home_abbr'], right_on = ['team_name', 'team_abbr']).drop(columns = ['team_name', 'team_abbr']).rename(columns = {
                'win_perc': 'home_win_perc',
               'first_downs': 'home_first_downs', 'fumbles': 'home_fumbles', 'fumbles_lost':'home_fumbles_lost', 'interceptions':'home_interceptions',
               'net_pass_yards': 'home_net_pass_yards', 'pass_attempts':'home_pass_attempts', 'pass_completions':'home_pass_completions',
               'pass_touchdowns':'home_pass_touchdowns', 'pass_yards':'home_pass_yards', 'penalties':'home_penalties', 'points':'home_points', 'rush_attempts':'home_rush_attempts',
               'rush_touchdowns':'home_rush_touchdowns', 'rush_yards':'home_rush_yards', 'time_of_possession':'home_time_of_possession', 'times_sacked':'home_times_sacked',
               'total_yards':'home_total_yards', 'turnovers':'home_turnovers', 'yards_from_penalties':'home_yards_from_penalties',
               'yards_lost_from_sacks': 'home_yards_lost_from_sacks', 'fourth_down_perc':'home_fourth_down_perc', 'third_down_perc':'home_third_down_perc'})

        agg_weekly_df = pd.merge(away_df,home_df,left_on = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'winning_name',
               'winning_abbr', 'week'], right_on = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'winning_name',
               'winning_abbr', 'week'])

        agg_weekly_df['win_perc_dif'] = agg_weekly_df['away_win_perc'] - agg_weekly_df['home_win_perc']
        agg_weekly_df['first_downs_dif'] = agg_weekly_df['away_first_downs'] - agg_weekly_df['home_first_downs']
        agg_weekly_df['fumbles_dif'] = agg_weekly_df['away_fumbles'] - agg_weekly_df['home_fumbles']
        agg_weekly_df['interceptions_dif'] = agg_weekly_df['away_interceptions'] - agg_weekly_df['home_interceptions']
        agg_weekly_df['net_pass_yards_dif'] = agg_weekly_df['away_net_pass_yards'] - agg_weekly_df['home_net_pass_yards']
        agg_weekly_df['pass_attempts_dif'] = agg_weekly_df['away_pass_attempts'] - agg_weekly_df['home_pass_attempts']
        agg_weekly_df['pass_completions_dif'] = agg_weekly_df['away_pass_completions'] - agg_weekly_df['home_pass_completions']
        agg_weekly_df['pass_touchdowns_dif'] = agg_weekly_df['away_pass_touchdowns'] - agg_weekly_df['home_pass_touchdowns']
        agg_weekly_df['pass_yards_dif'] = agg_weekly_df['away_pass_yards'] - agg_weekly_df['home_pass_yards']
        agg_weekly_df['penalties_dif'] = agg_weekly_df['away_penalties'] - agg_weekly_df['home_penalties']
        agg_weekly_df['points_dif'] = agg_weekly_df['away_points'] - agg_weekly_df['home_points']
        agg_weekly_df['rush_attempts_dif'] = agg_weekly_df['away_rush_attempts'] - agg_weekly_df['home_rush_attempts']
        agg_weekly_df['rush_touchdowns_dif'] = agg_weekly_df['away_rush_touchdowns'] - agg_weekly_df['home_rush_touchdowns']
        agg_weekly_df['rush_yards_dif'] = agg_weekly_df['away_rush_yards'] - agg_weekly_df['home_rush_yards']
        agg_weekly_df['time_of_possession_dif'] = agg_weekly_df['away_time_of_possession'] - agg_weekly_df['home_time_of_possession']
        agg_weekly_df['times_sacked_dif'] = agg_weekly_df['away_times_sacked'] - agg_weekly_df['home_times_sacked']
        agg_weekly_df['total_yards_dif'] = agg_weekly_df['away_total_yards'] - agg_weekly_df['home_total_yards']
        agg_weekly_df['turnovers_dif'] = agg_weekly_df['away_turnovers'] - agg_weekly_df['home_turnovers']
        agg_weekly_df['yards_from_penalties_dif'] = agg_weekly_df['away_yards_from_penalties'] - agg_weekly_df['home_yards_from_penalties']
        agg_weekly_df['yards_lost_from_sacks_dif'] = agg_weekly_df['away_yards_lost_from_sacks'] - agg_weekly_df['home_yards_lost_from_sacks']
        agg_weekly_df['fourth_down_perc_dif'] = agg_weekly_df['away_fourth_down_perc'] - agg_weekly_df['home_fourth_down_perc']
        agg_weekly_df['third_down_perc_dif'] = agg_weekly_df['away_third_down_perc'] - agg_weekly_df['home_third_down_perc']

        agg_weekly_df = agg_weekly_df.drop(columns = ['away_win_perc',
               'away_first_downs', 'away_fumbles', 'away_fumbles_lost', 'away_interceptions',
               'away_net_pass_yards', 'away_pass_attempts','away_pass_completions',
               'away_pass_touchdowns', 'away_pass_yards', 'away_penalties', 'away_points', 'away_rush_attempts',
               'away_rush_touchdowns', 'away_rush_yards', 'away_time_of_possession', 'away_times_sacked',
               'away_total_yards', 'away_turnovers', 'away_yards_from_penalties',
               'away_yards_lost_from_sacks','away_fourth_down_perc', 'away_third_down_perc','home_win_perc',
               'home_first_downs', 'home_fumbles', 'home_fumbles_lost', 'home_interceptions',
               'home_net_pass_yards', 'home_pass_attempts','home_pass_completions',
               'home_pass_touchdowns', 'home_pass_yards', 'home_penalties', 'home_points', 'home_rush_attempts',
               'home_rush_touchdowns', 'home_rush_yards', 'home_time_of_possession', 'home_times_sacked',
               'home_total_yards', 'home_turnovers', 'home_yards_from_penalties',
               'home_yards_lost_from_sacks','home_fourth_down_perc', 'home_third_down_perc'])
        
        if (agg_weekly_df['winning_name'].isnull().values.any() and weeks[w] > 3):
            agg_weekly_df['result'] = np.nan
            print(f"Week {weeks[w]} games have not finished yet.")
        else:
            agg_weekly_df['result'] = agg_weekly_df['winning_name'] == agg_weekly_df['away_name']
            agg_weekly_df['result'] = agg_weekly_df['result'].astype('float')
        agg_weekly_df = agg_weekly_df.drop(columns = ['winning_name', 'winning_abbr'])
        agg_games_df = pd.concat([agg_games_df, agg_weekly_df])
    agg_games_df = agg_games_df.reset_index().drop(columns = 'index')
    agg_games_df = agg_games_df.drop(index = 20, axis=0)
    return agg_games_df

def get_elo():
    elo_df = pd.read_csv('nfl_elo_latest.csv')
    elo_df = elo_df.drop(columns = ['season','neutral' ,'playoff', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post',
           'qbelo1_pre', 'qbelo2_pre', 'qb1', 'qb2', 'qb1_adj', 'qb2_adj', 'qbelo_prob1', 'qbelo_prob2',
           'qb1_game_value', 'qb2_game_value', 'qb1_value_post', 'qb2_value_post',
           'qbelo1_post', 'qbelo2_post', 'score1', 'score2'])
    elo_df.date = pd.to_datetime(elo_df.date)
    elo_df = elo_df[elo_df.date < '01-05-2021']

    elo_df['team1'] = elo_df['team1'].replace(['KC', 'JAX', 'CAR', 'BAL', 'BUF', 'MIN', 'DET', 'ATL', 'NE', 'WSH',
           'CIN', 'NO', 'SF', 'LAR', 'NYG', 'DEN', 'CLE', 'IND', 'TEN', 'NYJ',
           'TB', 'MIA', 'PIT', 'PHI', 'GB', 'CHI', 'DAL', 'ARI', 'LAC', 'HOU',
           'SEA', 'OAK'],
            ['kan','jax','car', 'rav', 'buf', 'min', 'det', 'atl', 'nwe', 'was', 
            'cin', 'nor', 'sfo', 'ram', 'nyg', 'den', 'cle', 'clt', 'oti', 'nyj', 
             'tam','mia', 'pit', 'phi', 'gnb', 'chi', 'dal', 'crd', 'sdg', 'htx', 'sea', 'rai' ])
    elo_df['team2'] = elo_df['team2'].replace(['KC', 'JAX', 'CAR', 'BAL', 'BUF', 'MIN', 'DET', 'ATL', 'NE', 'WSH',
           'CIN', 'NO', 'SF', 'LAR', 'NYG', 'DEN', 'CLE', 'IND', 'TEN', 'NYJ',
           'TB', 'MIA', 'PIT', 'PHI', 'GB', 'CHI', 'DAL', 'ARI', 'LAC', 'HOU',
           'SEA', 'OAK'],
            ['kan','jax','car', 'rav', 'buf', 'min', 'det', 'atl', 'nwe', 'was', 
            'cin', 'nor', 'sfo', 'ram', 'nyg', 'den', 'cle', 'clt', 'oti', 'nyj', 
             'tam','mia', 'pit', 'phi', 'gnb', 'chi', 'dal', 'crd', 'sdg', 'htx', 'sea', 'rai' ])
    return elo_df

def merge_rankings(agg_games_df,elo_df):
    agg_games_df = pd.merge(agg_games_df, elo_df, how = 'inner', left_on = ['home_abbr', 'away_abbr'], right_on = ['team1', 'team2']).drop(columns = ['date','team1', 'team2'])
    agg_games_df['elo_dif'] = agg_games_df['elo2_pre'] - agg_games_df['elo1_pre']
    agg_games_df['qb_dif'] = agg_games_df['qb2_value_pre'] - agg_games_df['qb1_value_pre']
    agg_games_df = agg_games_df.drop(columns = ['elo1_pre', 'elo2_pre', 'qb1_value_pre', 'qb2_value_pre'])
    return agg_games_df

def prep_test_train(current_week,weeks,year):
    current_week = current_week + 1
    schedule_df  = get_schedule(year)
    weeks_games_df = game_data_up_to_week(weeks,year)
    agg_games_df = agg_weekly_data(schedule_df,weeks_games_df,current_week,weeks)
    elo_df = get_elo()
    agg_games_df = merge_rankings(agg_games_df, elo_df)
    train_df = agg_games_df[agg_games_df.result.notna()]
    current_week = current_week - 1
    test_df = agg_games_df[agg_games_df.week == current_week]
    return test_df, train_df

def display(y_pred,X_test):
    for g in range(len(y_pred)):
        win_prob = round(y_pred[g],2)
        away_team = X_test.reset_index().drop(columns = 'index').loc[g,'away_name']
        home_team = X_test.reset_index().drop(columns = 'index').loc[g,'home_name']
        print(f'The {away_team} have a probability of {win_prob} of beating the {home_team}.')

# %%
current_week = 16
weeks = list(range(1,current_week + 1))
year = 2020

pred_games_df, comp_games_df = prep_test_train(current_week,weeks,year)

# %%
pred_games_df
# Out:
#                 away_name away_abbr  ...     elo_dif      qb_dif
# 207     Minnesota Vikings       min  ...  -88.006647 -130.761526
# 208  Tampa Bay Buccaneers       tam  ...  207.592902   41.151816
# 209   San Francisco 49ers       sfo  ...   40.708251 -141.959484
# 210        Miami Dolphins       mia  ...   21.049534 -110.257822
# 211       New York Giants       nyg  ... -309.667260  -86.720052
# 212    Indianapolis Colts       clt  ...  -78.368493  -26.678916
# 213      Cleveland Browns       cle  ...  157.679395   43.652214
# 214       Atlanta Falcons       atl  ... -224.706390  -77.619557
# 215         Chicago Bears       chi  ...  196.712360   60.454267
# 216    Cincinnati Bengals       cin  ...  -42.199460  -70.984733
# 217     Carolina Panthers       car  ...   43.078008   69.027420
# 218        Denver Broncos       den  ...   44.212728  -96.310991
# 219      Los Angeles Rams       ram  ...  -58.851004  -76.433909
# 220   Philadelphia Eagles       phi  ...   99.265671   43.608377
# 221      Tennessee Titans       oti  ...  -12.808087    4.023072
# 222         Buffalo Bills       buf  ...   56.984641   58.208704
#
# [16 rows x 30 columns]

# %%
comp_games_df
# Out:
#                away_name away_abbr  ...     elo_dif     qb_dif
# 0     Cincinnati Bengals       cin  ...  -59.457909  -9.344132
# 1      Minnesota Vikings       min  ...   80.630237   2.903195
# 2        New York Giants       nyg  ... -166.404690   4.539082
# 3      Carolina Panthers       car  ...  -87.215650  11.924533
# 4         Denver Broncos       den  ...  -45.328094 -94.953289
# ..                   ...       ...  ...         ...        ...
# 218       Denver Broncos       den  ...   44.212728 -96.310991
# 219     Los Angeles Rams       ram  ...  -58.851004 -76.433909
# 220  Philadelphia Eagles       phi  ...   99.265671  43.608377
# 221     Tennessee Titans       oti  ...  -12.808087   4.023072
# 222        Buffalo Bills       buf  ...   56.984641  58.208704
#
# [223 rows x 30 columns]

# %%
msk = np.random.rand(len(comp_games_df)) < 0.8

train_df = comp_games_df[msk]
test_df = comp_games_df[~msk]

X_train = train_df.drop(columns = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'week','result'])
y_train = train_df[['result']] 
X_test = test_df.drop(columns = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'week','result'])
y_test = test_df[['result']]

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(penalty='l1', dual=False, tol=0.001, C=1.0, fit_intercept=True, 
                   intercept_scaling=1, class_weight='balanced', random_state=None, 
                   solver='liblinear', max_iter=1000, multi_class='ovr', verbose=0)

clf.fit(X_train, np.ravel(y_train.values))
y_pred = clf.predict_proba(X_test)
y_pred = y_pred[:,1]

display(y_pred,test_df)
# Out:
# The Cincinnati Bengals have a probability of 0.08 of beating the Cleveland Browns.
# The Minnesota Vikings have a probability of 0.19 of beating the Indianapolis Colts.
# The Buffalo Bills have a probability of 0.73 of beating the Miami Dolphins.
# The Baltimore Ravens have a probability of 0.69 of beating the Houston Texans.
# The New England Patriots have a probability of 0.65 of beating the Seattle Seahawks.
# The Baltimore Ravens have a probability of 0.92 of beating the Washington Football Team.
# The New York Giants have a probability of 0.38 of beating the Los Angeles Rams.
# The Buffalo Bills have a probability of 0.45 of beating the Las Vegas Raiders.
# The Atlanta Falcons have a probability of 0.07 of beating the Green Bay Packers.
# The Jacksonville Jaguars have a probability of 0.75 of beating the Houston Texans.
# The Cleveland Browns have a probability of 0.35 of beating the Pittsburgh Steelers.
# The Baltimore Ravens have a probability of 0.82 of beating the Philadelphia Eagles.
# The Houston Texans have a probability of 0.23 of beating the Tennessee Titans.
# The Denver Broncos have a probability of 0.16 of beating the New England Patriots.
# The New York Giants have a probability of 0.56 of beating the Philadelphia Eagles.
# The Dallas Cowboys have a probability of 0.6 of beating the Washington Football Team.
# The Buffalo Bills have a probability of 0.91 of beating the New York Jets.
# The Chicago Bears have a probability of 0.42 of beating the Tennessee Titans.
# The Carolina Panthers have a probability of 0.19 of beating the Kansas City Chiefs.
# The Indianapolis Colts have a probability of 0.55 of beating the Tennessee Titans.
# The Houston Texans have a probability of 0.27 of beating the Cleveland Browns.
# The Philadelphia Eagles have a probability of 0.46 of beating the New York Giants.
# The Jacksonville Jaguars have a probability of 0.05 of beating the Green Bay Packers.
# The Washington Football Team have a probability of 0.32 of beating the Detroit Lions.
# The Cincinnati Bengals have a probability of 0.16 of beating the Pittsburgh Steelers.
# The Pittsburgh Steelers have a probability of 0.91 of beating the Jacksonville Jaguars.
# The Green Bay Packers have a probability of 0.72 of beating the Indianapolis Colts.
# The Los Angeles Rams have a probability of 0.3 of beating the Tampa Bay Buccaneers.
# The Houston Texans have a probability of 0.5 of beating the Detroit Lions.
# The Las Vegas Raiders have a probability of 0.77 of beating the Atlanta Falcons.
# The Carolina Panthers have a probability of 0.53 of beating the Minnesota Vikings.
# The New Orleans Saints have a probability of 0.8 of beating the Denver Broncos.
# The Kansas City Chiefs have a probability of 0.59 of beating the Tampa Bay Buccaneers.
# The Chicago Bears have a probability of 0.26 of beating the Green Bay Packers.
# The Seattle Seahawks have a probability of 0.69 of beating the Philadelphia Eagles.
# The Las Vegas Raiders have a probability of 0.83 of beating the New York Jets.
# The New York Giants have a probability of 0.29 of beating the Seattle Seahawks.
# The New England Patriots have a probability of 0.61 of beating the Los Angeles Chargers.
# The Washington Football Team have a probability of 0.09 of beating the Pittsburgh Steelers.
# The Arizona Cardinals have a probability of 0.76 of beating the New York Giants.
# The New York Jets have a probability of 0.23 of beating the Seattle Seahawks.
# The Buffalo Bills have a probability of 0.78 of beating the Denver Broncos.
# The Carolina Panthers have a probability of 0.18 of beating the Green Bay Packers.
# The Seattle Seahawks have a probability of 0.8 of beating the Washington Football Team.
# The Tampa Bay Buccaneers have a probability of 0.83 of beating the Detroit Lions.
# The Indianapolis Colts have a probability of 0.27 of beating the Pittsburgh Steelers.
# The Philadelphia Eagles have a probability of 0.59 of beating the Dallas Cowboys.

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,np.round(y_pred))
# Out:
# 0.723404255319149

# %%
import xgboost as xgb

dtest = xgb.DMatrix(X_test, y_test, feature_names=X_test.columns)
dtrain = xgb.DMatrix(X_train, y_train,feature_names=X_train.columns)

param = {'verbosity':1, 
         'objective':'binary:hinge',
         'feature_selector': 'shuffle',
         'booster':'gblinear',
         'eval_metric' :'error',
         'learning_rate': 0.05}

evallist = [(dtrain, 'train'), (dtest, 'test')]

# %%
num_round = 1600
bst = xgb.train(param, dtrain, num_round, evallist)
# Out:
# [0]	train-error:0.494318	test-error:0.531915
# [1]	train-error:0.482955	test-error:0.510638
# [2]	train-error:0.460227	test-error:0.446809
# [3]	train-error:0.409091	test-error:0.425532
# [4]	train-error:0.397727	test-error:0.404255
# [5]	train-error:0.357955	test-error:0.382979
# [6]	train-error:0.335227	test-error:0.382979
# [7]	train-error:0.335227	test-error:0.361702
# [8]	train-error:0.329545	test-error:0.361702
# [9]	train-error:0.329545	test-error:0.361702
# [10]	train-error:0.340909	test-error:0.361702
# [11]	train-error:0.335227	test-error:0.361702
# [12]	train-error:0.329545	test-error:0.361702
# [13]	train-error:0.329545	test-error:0.340426
# [14]	train-error:0.335227	test-error:0.297872
# [15]	train-error:0.329545	test-error:0.297872
# [16]	train-error:0.329545	test-error:0.276596
# [17]	train-error:0.323864	test-error:0.276596
# [18]	train-error:0.318182	test-error:0.276596
# [19]	train-error:0.323864	test-error:0.276596
# [20]	train-error:0.323864	test-error:0.276596
# [21]	train-error:0.3125	test-error:0.276596
# [22]	train-error:0.301136	test-error:0.276596
# [23]	train-error:0.306818	test-error:0.276596
# [24]	train-error:0.3125	test-error:0.276596
# [25]	train-error:0.3125	test-error:0.276596
# [26]	train-error:0.3125	test-error:0.276596
# [27]	train-error:0.3125	test-error:0.276596
# [28]	train-error:0.3125	test-error:0.255319
# [29]	train-error:0.3125	test-error:0.255319
# [30]	train-error:0.301136	test-error:0.255319
# [31]	train-error:0.295455	test-error:0.255319
# [32]	train-error:0.295455	test-error:0.255319
# [33]	train-error:0.295455	test-error:0.255319
# [34]	train-error:0.306818	test-error:0.255319
# [35]	train-error:0.306818	test-error:0.255319
# [36]	train-error:0.301136	test-error:0.255319
# [37]	train-error:0.301136	test-error:0.255319
# [38]	train-error:0.301136	test-error:0.255319
# [39]	train-error:0.301136	test-error:0.255319
# [40]	train-error:0.306818	test-error:0.255319
# [41]	train-error:0.306818	test-error:0.255319
# [42]	train-error:0.306818	test-error:0.255319
# [43]	train-error:0.306818	test-error:0.255319
# [44]	train-error:0.301136	test-error:0.255319
# [45]	train-error:0.301136	test-error:0.255319
# [46]	train-error:0.306818	test-error:0.255319
# [47]	train-error:0.306818	test-error:0.255319
# [48]	train-error:0.306818	test-error:0.255319
# [49]	train-error:0.3125	test-error:0.255319
# [50]	train-error:0.306818	test-error:0.255319
# [51]	train-error:0.306818	test-error:0.255319
# [52]	train-error:0.306818	test-error:0.255319
# [53]	train-error:0.306818	test-error:0.255319
# [122]	train-error:0.3125	test-error:0.255319
# [123]	train-error:0.3125	test-error:0.234043
# [124]	train-error:0.318182	test-error:0.255319
# [125]	train-error:0.318182	test-error:0.234043
# [126]	train-error:0.3125	test-error:0.234043
# [127]	train-error:0.318182	test-error:0.234043
# [128]	train-error:0.318182	test-error:0.255319
# [129]	train-error:0.318182	test-error:0.234043
# [130]	train-error:0.318182	test-error:0.255319
# [131]	train-error:0.318182	test-error:0.276596
# [132]	train-error:0.318182	test-error:0.234043
# [133]	train-error:0.318182	test-error:0.234043
# [134]	train-error:0.318182	test-error:0.255319
# [135]	train-error:0.3125	test-error:0.234043
# [136]	train-error:0.318182	test-error:0.255319
# [137]	train-error:0.3125	test-error:0.234043
# [138]	train-error:0.318182	test-error:0.255319
# [139]	train-error:0.318182	test-error:0.234043
# [140]	train-error:0.3125	test-error:0.255319
# [141]	train-error:0.3125	test-error:0.234043
# [142]	train-error:0.3125	test-error:0.255319
# [143]	train-error:0.3125	test-error:0.234043
# [144]	train-error:0.3125	test-error:0.234043
# [145]	train-error:0.306818	test-error:0.234043
# [146]	train-error:0.3125	test-error:0.255319
# [147]	train-error:0.3125	test-error:0.234043
# [148]	train-error:0.3125	test-error:0.255319
# [149]	train-error:0.3125	test-error:0.234043
# [150]	train-error:0.306818	test-error:0.255319
# [151]	train-error:0.3125	test-error:0.234043
# [152]	train-error:0.306818	test-error:0.255319
# [153]	train-error:0.3125	test-error:0.234043
# [154]	train-error:0.306818	test-error:0.234043
# [155]	train-error:0.306818	test-error:0.234043
# [156]	train-error:0.306818	test-error:0.234043
# [157]	train-error:0.306818	test-error:0.255319
# [158]	train-error:0.306818	test-error:0.234043
# [159]	train-error:0.306818	test-error:0.234043
# [160]	train-error:0.3125	test-error:0.255319
# [161]	train-error:0.306818	test-error:0.234043
# [162]	train-error:0.318182	test-error:0.234043
# [163]	train-error:0.3125	test-error:0.255319
# [164]	train-error:0.318182	test-error:0.234043
# [165]	train-error:0.318182	test-error:0.234043
# [166]	train-error:0.318182	test-error:0.234043
# [167]	train-error:0.318182	test-error:0.234043
# [168]	train-error:0.318182	test-error:0.234043
# [169]	train-error:0.318182	test-error:0.234043
# [170]	train-error:0.323864	test-error:0.234043
# [171]	train-error:0.329545	test-error:0.234043
# [172]	train-error:0.318182	test-error:0.234043
# [173]	train-error:0.323864	test-error:0.234043
# [174]	train-error:0.329545	test-error:0.234043
# [175]	train-error:0.323864	test-error:0.234043
# [176]	train-error:0.318182	test-error:0.234043
# [177]	train-error:0.323864	test-error:0.255319
# [178]	train-error:0.318182	test-error:0.234043
# [179]	train-error:0.323864	test-error:0.255319
# [180]	train-error:0.323864	test-error:0.234043
# [181]	train-error:0.318182	test-error:0.234043
# [182]	train-error:0.323864	test-error:0.234043
# [183]	train-error:0.323864	test-error:0.234043
# [184]	train-error:0.318182	test-error:0.255319
# [185]	train-error:0.318182	test-error:0.234043
# [186]	train-error:0.318182	test-error:0.234043
# [187]	train-error:0.318182	test-error:0.255319
# [188]	train-error:0.318182	test-error:0.234043
# [189]	train-error:0.318182	test-error:0.234043
# [190]	train-error:0.318182	test-error:0.234043
# [191]	train-error:0.318182	test-error:0.234043
# [192]	train-error:0.318182	test-error:0.234043
# [193]	train-error:0.318182	test-error:0.234043
# [194]	train-error:0.318182	test-error:0.234043
# [195]	train-error:0.318182	test-error:0.234043
# [196]	train-error:0.318182	test-error:0.234043
# [197]	train-error:0.318182	test-error:0.234043
# [198]	train-error:0.318182	test-error:0.234043
# [199]	train-error:0.318182	test-error:0.255319
# [200]	train-error:0.318182	test-error:0.234043
# [201]	train-error:0.318182	test-error:0.234043
# [202]	train-error:0.318182	test-error:0.234043
# [203]	train-error:0.318182	test-error:0.234043
# [204]	train-error:0.318182	test-error:0.255319
# [205]	train-error:0.318182	test-error:0.234043
# [206]	train-error:0.318182	test-error:0.234043
# [207]	train-error:0.318182	test-error:0.234043
# [208]	train-error:0.318182	test-error:0.234043
# [209]	train-error:0.318182	test-error:0.234043
# [210]	train-error:0.318182	test-error:0.234043
# [211]	train-error:0.318182	test-error:0.234043
# [212]	train-error:0.318182	test-error:0.234043
# [213]	train-error:0.318182	test-error:0.234043
# [214]	train-error:0.318182	test-error:0.234043
# [215]	train-error:0.318182	test-error:0.234043
# [216]	train-error:0.318182	test-error:0.255319
# [217]	train-error:0.318182	test-error:0.234043
# [218]	train-error:0.318182	test-error:0.234043
# [219]	train-error:0.318182	test-error:0.276596
# [220]	train-error:0.318182	test-error:0.234043
# [221]	train-error:0.318182	test-error:0.234043
# [222]	train-error:0.318182	test-error:0.234043
# [223]	train-error:0.318182	test-error:0.234043
# [224]	train-error:0.318182	test-error:0.234043
# [225]	train-error:0.318182	test-error:0.234043
# [226]	train-error:0.318182	test-error:0.276596
# [227]	train-error:0.318182	test-error:0.234043
# [228]	train-error:0.318182	test-error:0.234043
# [229]	train-error:0.318182	test-error:0.255319
# [230]	train-error:0.318182	test-error:0.234043
# [231]	train-error:0.318182	test-error:0.234043
# [232]	train-error:0.318182	test-error:0.276596
# [233]	train-error:0.318182	test-error:0.234043
# [234]	train-error:0.3125	test-error:0.234043
# [235]	train-error:0.318182	test-error:0.276596
# [236]	train-error:0.318182	test-error:0.234043
# [237]	train-error:0.318182	test-error:0.234043
# [238]	train-error:0.318182	test-error:0.255319
# [239]	train-error:0.318182	test-error:0.234043
# [240]	train-error:0.318182	test-error:0.234043
# [241]	train-error:0.318182	test-error:0.255319
# [242]	train-error:0.3125	test-error:0.234043
# [243]	train-error:0.318182	test-error:0.234043
# [244]	train-error:0.318182	test-error:0.234043
# [245]	train-error:0.318182	test-error:0.255319
# [246]	train-error:0.318182	test-error:0.255319
# [247]	train-error:0.318182	test-error:0.234043
# [248]	train-error:0.318182	test-error:0.276596
# [249]	train-error:0.318182	test-error:0.255319
# [250]	train-error:0.318182	test-error:0.255319
# [251]	train-error:0.318182	test-error:0.255319
# [252]	train-error:0.318182	test-error:0.255319
# [253]	train-error:0.318182	test-error:0.255319
# [254]	train-error:0.318182	test-error:0.255319
# [255]	train-error:0.318182	test-error:0.255319
# [256]	train-error:0.318182	test-error:0.255319
# [393]	train-error:0.306818	test-error:0.276596
# [394]	train-error:0.306818	test-error:0.276596
# [395]	train-error:0.3125	test-error:0.276596
# [396]	train-error:0.3125	test-error:0.276596
# [397]	train-error:0.306818	test-error:0.276596
# [398]	train-error:0.3125	test-error:0.276596
# [399]	train-error:0.306818	test-error:0.276596
# [400]	train-error:0.3125	test-error:0.276596
# [401]	train-error:0.306818	test-error:0.276596
# [402]	train-error:0.3125	test-error:0.276596
# [403]	train-error:0.3125	test-error:0.276596
# [404]	train-error:0.3125	test-error:0.276596
# [405]	train-error:0.3125	test-error:0.276596
# [406]	train-error:0.3125	test-error:0.276596
# [407]	train-error:0.3125	test-error:0.276596
# [408]	train-error:0.3125	test-error:0.276596
# [409]	train-error:0.3125	test-error:0.276596
# [410]	train-error:0.3125	test-error:0.276596
# [411]	train-error:0.306818	test-error:0.276596
# [412]	train-error:0.3125	test-error:0.276596
# [413]	train-error:0.3125	test-error:0.276596
# [414]	train-error:0.3125	test-error:0.276596
# [415]	train-error:0.3125	test-error:0.276596
# [416]	train-error:0.3125	test-error:0.276596
# [417]	train-error:0.3125	test-error:0.276596
# [418]	train-error:0.3125	test-error:0.276596
# [419]	train-error:0.3125	test-error:0.276596
# [420]	train-error:0.3125	test-error:0.276596
# [421]	train-error:0.3125	test-error:0.276596
# [422]	train-error:0.3125	test-error:0.276596
# [423]	train-error:0.3125	test-error:0.276596
# [424]	train-error:0.3125	test-error:0.276596
# [425]	train-error:0.3125	test-error:0.276596
# [426]	train-error:0.3125	test-error:0.276596
# [427]	train-error:0.3125	test-error:0.276596
# [428]	train-error:0.3125	test-error:0.276596
# [429]	train-error:0.3125	test-error:0.276596
# [430]	train-error:0.3125	test-error:0.276596
# [431]	train-error:0.3125	test-error:0.276596
# [432]	train-error:0.3125	test-error:0.276596
# [433]	train-error:0.3125	test-error:0.276596
# [434]	train-error:0.3125	test-error:0.276596
# [435]	train-error:0.3125	test-error:0.276596
# [436]	train-error:0.3125	test-error:0.276596
# [437]	train-error:0.3125	test-error:0.276596
# [438]	train-error:0.3125	test-error:0.276596
# [439]	train-error:0.3125	test-error:0.276596
# [440]	train-error:0.3125	test-error:0.276596
# [441]	train-error:0.3125	test-error:0.276596
# [442]	train-error:0.3125	test-error:0.276596
# [443]	train-error:0.3125	test-error:0.276596
# [444]	train-error:0.3125	test-error:0.276596
# [445]	train-error:0.3125	test-error:0.276596
# [446]	train-error:0.3125	test-error:0.276596
# [447]	train-error:0.3125	test-error:0.276596
# [448]	train-error:0.3125	test-error:0.276596
# [449]	train-error:0.3125	test-error:0.276596
# [450]	train-error:0.3125	test-error:0.276596
# [451]	train-error:0.306818	test-error:0.276596
# [452]	train-error:0.3125	test-error:0.276596
# [453]	train-error:0.3125	test-error:0.276596
# [454]	train-error:0.3125	test-error:0.276596
# [455]	train-error:0.3125	test-error:0.276596
# [456]	train-error:0.3125	test-error:0.276596
# [457]	train-error:0.3125	test-error:0.276596
# [458]	train-error:0.3125	test-error:0.276596
# [459]	train-error:0.3125	test-error:0.276596
# [528]	train-error:0.306818	test-error:0.276596
# [529]	train-error:0.306818	test-error:0.276596
# [530]	train-error:0.306818	test-error:0.276596
# [531]	train-error:0.306818	test-error:0.276596
# [532]	train-error:0.306818	test-error:0.276596
# [533]	train-error:0.306818	test-error:0.276596
# [534]	train-error:0.306818	test-error:0.276596
# [535]	train-error:0.306818	test-error:0.276596
# [536]	train-error:0.306818	test-error:0.276596
# [537]	train-error:0.306818	test-error:0.276596
# [538]	train-error:0.306818	test-error:0.276596
# [539]	train-error:0.306818	test-error:0.276596
# [540]	train-error:0.306818	test-error:0.276596
# [541]	train-error:0.306818	test-error:0.276596
# [542]	train-error:0.306818	test-error:0.276596
# [543]	train-error:0.306818	test-error:0.276596
# [544]	train-error:0.306818	test-error:0.276596
# [545]	train-error:0.306818	test-error:0.276596
# [546]	train-error:0.306818	test-error:0.276596
# [547]	train-error:0.306818	test-error:0.276596
# [548]	train-error:0.306818	test-error:0.276596
# [549]	train-error:0.306818	test-error:0.276596
# [550]	train-error:0.306818	test-error:0.276596
# [551]	train-error:0.306818	test-error:0.276596
# [552]	train-error:0.306818	test-error:0.276596
# [553]	train-error:0.306818	test-error:0.276596
# [554]	train-error:0.306818	test-error:0.276596
# [555]	train-error:0.306818	test-error:0.276596
# [556]	train-error:0.306818	test-error:0.276596
# [557]	train-error:0.306818	test-error:0.276596
# [558]	train-error:0.301136	test-error:0.276596
# [559]	train-error:0.306818	test-error:0.276596
# [560]	train-error:0.306818	test-error:0.276596
# [561]	train-error:0.306818	test-error:0.276596
# [562]	train-error:0.306818	test-error:0.276596
# [563]	train-error:0.306818	test-error:0.276596
# [564]	train-error:0.306818	test-error:0.276596
# [565]	train-error:0.306818	test-error:0.276596
# [566]	train-error:0.301136	test-error:0.276596
# [567]	train-error:0.306818	test-error:0.276596
# [568]	train-error:0.306818	test-error:0.276596
# [569]	train-error:0.306818	test-error:0.276596
# [570]	train-error:0.301136	test-error:0.276596
# [571]	train-error:0.306818	test-error:0.276596
# [572]	train-error:0.301136	test-error:0.276596
# [573]	train-error:0.306818	test-error:0.276596
# [574]	train-error:0.301136	test-error:0.276596
# [575]	train-error:0.306818	test-error:0.276596
# [576]	train-error:0.301136	test-error:0.276596
# [577]	train-error:0.306818	test-error:0.276596
# [578]	train-error:0.301136	test-error:0.276596
# [579]	train-error:0.306818	test-error:0.276596
# [580]	train-error:0.301136	test-error:0.276596
# [581]	train-error:0.301136	test-error:0.276596
# [582]	train-error:0.301136	test-error:0.276596
# [583]	train-error:0.306818	test-error:0.276596
# [584]	train-error:0.301136	test-error:0.276596
# [585]	train-error:0.301136	test-error:0.276596
# [586]	train-error:0.301136	test-error:0.276596
# [587]	train-error:0.301136	test-error:0.276596
# [588]	train-error:0.301136	test-error:0.276596
# [589]	train-error:0.301136	test-error:0.276596
# [590]	train-error:0.301136	test-error:0.276596
# [591]	train-error:0.301136	test-error:0.276596
# [592]	train-error:0.301136	test-error:0.276596
# [593]	train-error:0.301136	test-error:0.276596
# [594]	train-error:0.301136	test-error:0.276596
# [595]	train-error:0.301136	test-error:0.276596
# [596]	train-error:0.301136	test-error:0.276596
# [597]	train-error:0.301136	test-error:0.276596
# [598]	train-error:0.301136	test-error:0.276596
# [599]	train-error:0.301136	test-error:0.276596
# [600]	train-error:0.301136	test-error:0.276596
# [601]	train-error:0.301136	test-error:0.276596
# [602]	train-error:0.301136	test-error:0.276596
# [603]	train-error:0.301136	test-error:0.276596
# [604]	train-error:0.301136	test-error:0.276596
# [605]	train-error:0.301136	test-error:0.276596
# [606]	train-error:0.301136	test-error:0.276596
# [607]	train-error:0.301136	test-error:0.276596
# [608]	train-error:0.301136	test-error:0.276596
# [609]	train-error:0.301136	test-error:0.276596
# [610]	train-error:0.301136	test-error:0.276596
# [611]	train-error:0.301136	test-error:0.276596
# [612]	train-error:0.301136	test-error:0.276596
# [613]	train-error:0.301136	test-error:0.276596
# [614]	train-error:0.301136	test-error:0.276596
# [615]	train-error:0.301136	test-error:0.276596
# [616]	train-error:0.301136	test-error:0.276596
# [617]	train-error:0.301136	test-error:0.276596
# [618]	train-error:0.301136	test-error:0.276596
# [619]	train-error:0.301136	test-error:0.276596
# [620]	train-error:0.301136	test-error:0.276596
# [621]	train-error:0.301136	test-error:0.276596
# [622]	train-error:0.301136	test-error:0.276596
# [623]	train-error:0.301136	test-error:0.276596
# [624]	train-error:0.301136	test-error:0.276596
# [625]	train-error:0.301136	test-error:0.276596
# [626]	train-error:0.301136	test-error:0.276596
# [627]	train-error:0.301136	test-error:0.276596
# [628]	train-error:0.301136	test-error:0.276596
# [629]	train-error:0.301136	test-error:0.276596
# [630]	train-error:0.301136	test-error:0.276596
# [631]	train-error:0.301136	test-error:0.276596
# [632]	train-error:0.301136	test-error:0.276596
# [633]	train-error:0.301136	test-error:0.276596
# [634]	train-error:0.301136	test-error:0.276596
# [635]	train-error:0.301136	test-error:0.276596
# [636]	train-error:0.301136	test-error:0.276596
# [637]	train-error:0.301136	test-error:0.276596
# [638]	train-error:0.301136	test-error:0.276596
# [639]	train-error:0.301136	test-error:0.276596
# [640]	train-error:0.301136	test-error:0.276596
# [641]	train-error:0.301136	test-error:0.276596
# [642]	train-error:0.301136	test-error:0.276596
# [643]	train-error:0.301136	test-error:0.276596
# [644]	train-error:0.301136	test-error:0.276596
# [645]	train-error:0.301136	test-error:0.276596
# [646]	train-error:0.301136	test-error:0.276596
# [647]	train-error:0.301136	test-error:0.276596
# [648]	train-error:0.301136	test-error:0.276596
# [649]	train-error:0.301136	test-error:0.276596
# [650]	train-error:0.301136	test-error:0.276596
# [651]	train-error:0.301136	test-error:0.276596
# [652]	train-error:0.301136	test-error:0.276596
# [653]	train-error:0.301136	test-error:0.276596
# [654]	train-error:0.301136	test-error:0.276596
# [655]	train-error:0.301136	test-error:0.276596
# [656]	train-error:0.301136	test-error:0.276596
# [657]	train-error:0.301136	test-error:0.276596
# [658]	train-error:0.301136	test-error:0.276596
# [659]	train-error:0.301136	test-error:0.276596
# [660]	train-error:0.301136	test-error:0.276596
# [661]	train-error:0.301136	test-error:0.276596
# [662]	train-error:0.301136	test-error:0.276596
# [663]	train-error:0.301136	test-error:0.276596
# [664]	train-error:0.301136	test-error:0.276596
# [665]	train-error:0.301136	test-error:0.276596
# [666]	train-error:0.301136	test-error:0.276596
# [667]	train-error:0.301136	test-error:0.276596
# [668]	train-error:0.301136	test-error:0.276596
# [669]	train-error:0.301136	test-error:0.276596
# [670]	train-error:0.301136	test-error:0.276596
# [671]	train-error:0.301136	test-error:0.276596
# [672]	train-error:0.301136	test-error:0.276596
# [673]	train-error:0.301136	test-error:0.276596
# [674]	train-error:0.301136	test-error:0.276596
# [675]	train-error:0.301136	test-error:0.276596
# [676]	train-error:0.301136	test-error:0.276596
# [677]	train-error:0.301136	test-error:0.276596
# [678]	train-error:0.301136	test-error:0.276596
# [679]	train-error:0.301136	test-error:0.276596
# [680]	train-error:0.301136	test-error:0.276596
# [681]	train-error:0.301136	test-error:0.276596
# [682]	train-error:0.301136	test-error:0.276596
# [683]	train-error:0.301136	test-error:0.276596
# [684]	train-error:0.301136	test-error:0.276596
# [685]	train-error:0.301136	test-error:0.276596
# [686]	train-error:0.301136	test-error:0.276596
# [687]	train-error:0.301136	test-error:0.276596
# [688]	train-error:0.301136	test-error:0.276596
# [689]	train-error:0.301136	test-error:0.276596
# [690]	train-error:0.301136	test-error:0.276596
# [691]	train-error:0.301136	test-error:0.276596
# [692]	train-error:0.301136	test-error:0.276596
# [693]	train-error:0.301136	test-error:0.276596
# [694]	train-error:0.301136	test-error:0.276596
# [695]	train-error:0.301136	test-error:0.276596
# [696]	train-error:0.301136	test-error:0.276596
# [697]	train-error:0.301136	test-error:0.276596
# [698]	train-error:0.301136	test-error:0.276596
# [699]	train-error:0.301136	test-error:0.276596
# [700]	train-error:0.301136	test-error:0.276596
# [701]	train-error:0.301136	test-error:0.276596
# [702]	train-error:0.301136	test-error:0.276596
# [703]	train-error:0.301136	test-error:0.276596
# [704]	train-error:0.301136	test-error:0.276596
# [705]	train-error:0.301136	test-error:0.276596
# [706]	train-error:0.301136	test-error:0.276596
# [707]	train-error:0.301136	test-error:0.276596
# [708]	train-error:0.301136	test-error:0.276596
# [709]	train-error:0.301136	test-error:0.276596
# [710]	train-error:0.301136	test-error:0.276596
# [711]	train-error:0.301136	test-error:0.276596
# [712]	train-error:0.301136	test-error:0.276596
# [713]	train-error:0.301136	test-error:0.276596
# [714]	train-error:0.301136	test-error:0.276596
# [715]	train-error:0.301136	test-error:0.276596
# [716]	train-error:0.301136	test-error:0.276596
# [717]	train-error:0.301136	test-error:0.276596
# [718]	train-error:0.301136	test-error:0.276596
# [719]	train-error:0.301136	test-error:0.276596
# [720]	train-error:0.301136	test-error:0.276596
# [721]	train-error:0.301136	test-error:0.276596
# [722]	train-error:0.301136	test-error:0.276596
# [723]	train-error:0.301136	test-error:0.276596
# [724]	train-error:0.301136	test-error:0.276596
# [725]	train-error:0.301136	test-error:0.255319
# [726]	train-error:0.301136	test-error:0.276596
# [727]	train-error:0.301136	test-error:0.276596
# [728]	train-error:0.301136	test-error:0.276596
# [729]	train-error:0.301136	test-error:0.255319
# [730]	train-error:0.301136	test-error:0.276596
# [731]	train-error:0.301136	test-error:0.255319
# [732]	train-error:0.301136	test-error:0.255319
# [733]	train-error:0.301136	test-error:0.255319
# [734]	train-error:0.301136	test-error:0.276596
# [735]	train-error:0.301136	test-error:0.255319
# [736]	train-error:0.301136	test-error:0.276596
# [737]	train-error:0.301136	test-error:0.255319
# [738]	train-error:0.301136	test-error:0.255319
# [739]	train-error:0.301136	test-error:0.255319
# [740]	train-error:0.301136	test-error:0.255319
# [741]	train-error:0.301136	test-error:0.255319
# [742]	train-error:0.301136	test-error:0.255319
# [743]	train-error:0.301136	test-error:0.255319
# [744]	train-error:0.301136	test-error:0.255319
# [745]	train-error:0.301136	test-error:0.255319
# [746]	train-error:0.301136	test-error:0.255319
# [747]	train-error:0.301136	test-error:0.255319
# [748]	train-error:0.301136	test-error:0.255319
# [749]	train-error:0.301136	test-error:0.276596
# [750]	train-error:0.301136	test-error:0.255319
# [751]	train-error:0.301136	test-error:0.255319
# [752]	train-error:0.301136	test-error:0.255319
# [753]	train-error:0.301136	test-error:0.255319
# [754]	train-error:0.301136	test-error:0.255319
# [755]	train-error:0.301136	test-error:0.255319
# [756]	train-error:0.301136	test-error:0.255319
# [757]	train-error:0.301136	test-error:0.255319
# [758]	train-error:0.301136	test-error:0.255319
# [759]	train-error:0.301136	test-error:0.255319
# [760]	train-error:0.301136	test-error:0.255319
# [761]	train-error:0.301136	test-error:0.255319
# [762]	train-error:0.301136	test-error:0.255319
# [763]	train-error:0.301136	test-error:0.255319
# [764]	train-error:0.301136	test-error:0.255319
# [765]	train-error:0.301136	test-error:0.255319
# [766]	train-error:0.301136	test-error:0.255319
# [767]	train-error:0.301136	test-error:0.255319
# [768]	train-error:0.301136	test-error:0.255319
# [769]	train-error:0.301136	test-error:0.255319
# [770]	train-error:0.301136	test-error:0.255319
# [771]	train-error:0.301136	test-error:0.255319
# [772]	train-error:0.301136	test-error:0.255319
# [773]	train-error:0.301136	test-error:0.255319
# [774]	train-error:0.301136	test-error:0.255319
# [775]	train-error:0.301136	test-error:0.255319
# [776]	train-error:0.301136	test-error:0.255319
# [777]	train-error:0.306818	test-error:0.255319
# [778]	train-error:0.301136	test-error:0.255319
# [779]	train-error:0.301136	test-error:0.255319
# [780]	train-error:0.301136	test-error:0.255319
# [781]	train-error:0.301136	test-error:0.255319
# [782]	train-error:0.301136	test-error:0.255319
# [783]	train-error:0.306818	test-error:0.255319
# [784]	train-error:0.301136	test-error:0.255319
# [785]	train-error:0.306818	test-error:0.255319
# [786]	train-error:0.301136	test-error:0.255319
# [787]	train-error:0.306818	test-error:0.255319
# [788]	train-error:0.306818	test-error:0.255319
# [789]	train-error:0.306818	test-error:0.255319
# [790]	train-error:0.306818	test-error:0.255319
# [791]	train-error:0.301136	test-error:0.255319
# [792]	train-error:0.306818	test-error:0.255319
# [793]	train-error:0.306818	test-error:0.255319
# [794]	train-error:0.306818	test-error:0.255319
# [795]	train-error:0.306818	test-error:0.255319
# [796]	train-error:0.301136	test-error:0.255319
# [797]	train-error:0.306818	test-error:0.255319
# [798]	train-error:0.306818	test-error:0.255319
# [1002]	train-error:0.3125	test-error:0.276596
# [1003]	train-error:0.306818	test-error:0.276596
# [1004]	train-error:0.3125	test-error:0.276596
# [1005]	train-error:0.306818	test-error:0.276596
# [1006]	train-error:0.306818	test-error:0.276596
# [1007]	train-error:0.306818	test-error:0.276596
# [1008]	train-error:0.306818	test-error:0.276596
# [1009]	train-error:0.3125	test-error:0.276596
# [1010]	train-error:0.306818	test-error:0.276596
# [1011]	train-error:0.3125	test-error:0.276596
# [1012]	train-error:0.306818	test-error:0.276596
# [1013]	train-error:0.306818	test-error:0.276596
# [1014]	train-error:0.306818	test-error:0.276596
# [1015]	train-error:0.306818	test-error:0.276596
# [1016]	train-error:0.306818	test-error:0.255319
# [1017]	train-error:0.3125	test-error:0.276596
# [1018]	train-error:0.306818	test-error:0.276596
# [1019]	train-error:0.3125	test-error:0.276596
# [1020]	train-error:0.306818	test-error:0.276596
# [1021]	train-error:0.306818	test-error:0.276596
# [1022]	train-error:0.3125	test-error:0.276596
# [1023]	train-error:0.306818	test-error:0.276596
# [1024]	train-error:0.3125	test-error:0.276596
# [1025]	train-error:0.306818	test-error:0.276596
# [1026]	train-error:0.3125	test-error:0.276596
# [1027]	train-error:0.306818	test-error:0.276596
# [1028]	train-error:0.3125	test-error:0.276596
# [1029]	train-error:0.306818	test-error:0.276596
# ...
# [1267]	train-error:0.301136	test-error:0.255319
# [1268]	train-error:0.301136	test-error:0.276596
# [1269]	train-error:0.301136	test-error:0.276596
# [1270]	train-error:0.301136	test-error:0.276596
# [1271]	train-error:0.301136	test-error:0.255319
# [1272]	train-error:0.301136	test-error:0.255319
# [1273]	train-error:0.301136	test-error:0.276596
# [1274]	train-error:0.301136	test-error:0.276596
# [1275]	train-error:0.301136	test-error:0.276596
# [1276]	train-error:0.301136	test-error:0.255319
# [1277]	train-error:0.301136	test-error:0.255319
# [1278]	train-error:0.301136	test-error:0.255319
# [1279]	train-error:0.301136	test-error:0.255319
# [1280]	train-error:0.301136	test-error:0.255319
# [1281]	train-error:0.301136	test-error:0.255319
# [1282]	train-error:0.301136	test-error:0.276596
# [1283]	train-error:0.301136	test-error:0.255319
# [1284]	train-error:0.301136	test-error:0.255319
# [1285]	train-error:0.301136	test-error:0.255319
# [1286]	train-error:0.301136	test-error:0.255319
# [1287]	train-error:0.301136	test-error:0.255319
# [1288]	train-error:0.301136	test-error:0.255319
# [1289]	train-error:0.301136	test-error:0.255319
# [1290]	train-error:0.301136	test-error:0.255319
# [1291]	train-error:0.301136	test-error:0.255319
# [1292]	train-error:0.301136	test-error:0.255319
# [1293]	train-error:0.301136	test-error:0.255319
# [1294]	train-error:0.301136	test-error:0.255319
# [1295]	train-error:0.301136	test-error:0.255319
# [1296]	train-error:0.301136	test-error:0.255319
# [1297]	train-error:0.301136	test-error:0.255319
# [1298]	train-error:0.301136	test-error:0.255319
# [1299]	train-error:0.301136	test-error:0.255319
# [1300]	train-error:0.301136	test-error:0.255319
# [1301]	train-error:0.301136	test-error:0.255319
# [1302]	train-error:0.301136	test-error:0.276596
# [1303]	train-error:0.301136	test-error:0.255319
# [1304]	train-error:0.301136	test-error:0.255319
# [1305]	train-error:0.301136	test-error:0.255319
# [1306]	train-error:0.301136	test-error:0.255319
# [1307]	train-error:0.301136	test-error:0.255319
# [1308]	train-error:0.301136	test-error:0.255319
# [1309]	train-error:0.301136	test-error:0.255319
# [1310]	train-error:0.301136	test-error:0.255319
# [1311]	train-error:0.301136	test-error:0.255319
# [1312]	train-error:0.301136	test-error:0.276596
# [1313]	train-error:0.301136	test-error:0.255319
# [1314]	train-error:0.301136	test-error:0.255319
# [1315]	train-error:0.301136	test-error:0.276596
# [1316]	train-error:0.301136	test-error:0.255319
# [1317]	train-error:0.301136	test-error:0.276596
# [1318]	train-error:0.301136	test-error:0.255319
# [1319]	train-error:0.301136	test-error:0.255319
# [1320]	train-error:0.301136	test-error:0.255319
# [1321]	train-error:0.301136	test-error:0.276596
# [1322]	train-error:0.301136	test-error:0.255319
# [1323]	train-error:0.301136	test-error:0.255319
# [1324]	train-error:0.301136	test-error:0.255319
# [1325]	train-error:0.301136	test-error:0.255319
# [1326]	train-error:0.301136	test-error:0.255319
# [1327]	train-error:0.301136	test-error:0.255319
# [1328]	train-error:0.301136	test-error:0.255319
# [1329]	train-error:0.301136	test-error:0.255319
# [1330]	train-error:0.301136	test-error:0.255319
# [1331]	train-error:0.301136	test-error:0.255319
# [1332]	train-error:0.301136	test-error:0.255319
# [1333]	train-error:0.301136	test-error:0.255319
# [1334]	train-error:0.301136	test-error:0.255319
# [1335]	train-error:0.301136	test-error:0.255319
# [1336]	train-error:0.301136	test-error:0.255319
# [1337]	train-error:0.301136	test-error:0.255319
# [1338]	train-error:0.301136	test-error:0.255319
# [1339]	train-error:0.301136	test-error:0.255319
# [1340]	train-error:0.301136	test-error:0.255319
# [1341]	train-error:0.301136	test-error:0.255319
# [1342]	train-error:0.301136	test-error:0.255319
# [1343]	train-error:0.301136	test-error:0.255319
# [1344]	train-error:0.301136	test-error:0.255319
# [1345]	train-error:0.301136	test-error:0.255319
# [1346]	train-error:0.301136	test-error:0.255319
# [1347]	train-error:0.301136	test-error:0.255319
# [1348]	train-error:0.301136	test-error:0.255319
# [1349]	train-error:0.301136	test-error:0.255319
# [1350]	train-error:0.301136	test-error:0.255319
# [1351]	train-error:0.301136	test-error:0.255319
# [1352]	train-error:0.301136	test-error:0.255319
# [1353]	train-error:0.301136	test-error:0.255319
# [1354]	train-error:0.301136	test-error:0.255319
# [1355]	train-error:0.301136	test-error:0.255319
# [1356]	train-error:0.301136	test-error:0.255319
# [1357]	train-error:0.295455	test-error:0.255319
# [1358]	train-error:0.301136	test-error:0.255319
# [1359]	train-error:0.301136	test-error:0.255319
# [1360]	train-error:0.301136	test-error:0.255319
# [1361]	train-error:0.301136	test-error:0.255319
# [1362]	train-error:0.301136	test-error:0.255319
# [1363]	train-error:0.295455	test-error:0.255319
# [1364]	train-error:0.301136	test-error:0.255319
# [1365]	train-error:0.301136	test-error:0.255319
# [1366]	train-error:0.301136	test-error:0.255319
# [1367]	train-error:0.295455	test-error:0.255319
# [1368]	train-error:0.301136	test-error:0.255319
# [1369]	train-error:0.301136	test-error:0.255319
# [1370]	train-error:0.301136	test-error:0.276596
# [1371]	train-error:0.301136	test-error:0.255319
# [1372]	train-error:0.301136	test-error:0.276596
# [1373]	train-error:0.295455	test-error:0.255319
# [1374]	train-error:0.301136	test-error:0.276596
# [1375]	train-error:0.301136	test-error:0.255319
# [1376]	train-error:0.295455	test-error:0.276596
# [1377]	train-error:0.301136	test-error:0.276596
# [1378]	train-error:0.295455	test-error:0.255319
# [1379]	train-error:0.301136	test-error:0.276596
# [1380]	train-error:0.301136	test-error:0.276596
# [1381]	train-error:0.295455	test-error:0.255319
# [1382]	train-error:0.301136	test-error:0.276596
# [1383]	train-error:0.301136	test-error:0.255319
# [1384]	train-error:0.295455	test-error:0.276596
# [1385]	train-error:0.295455	test-error:0.255319
# [1386]	train-error:0.301136	test-error:0.276596
# [1387]	train-error:0.295455	test-error:0.255319
# [1388]	train-error:0.295455	test-error:0.255319
# [1389]	train-error:0.301136	test-error:0.276596
# [1390]	train-error:0.295455	test-error:0.255319
# [1391]	train-error:0.301136	test-error:0.276596
# [1392]	train-error:0.295455	test-error:0.255319
# [1393]	train-error:0.295455	test-error:0.255319
# [1394]	train-error:0.301136	test-error:0.276596
# [1395]	train-error:0.295455	test-error:0.255319
# [1396]	train-error:0.301136	test-error:0.276596
# [1397]	train-error:0.295455	test-error:0.255319
# [1398]	train-error:0.295455	test-error:0.276596
# [1399]	train-error:0.295455	test-error:0.255319
# [1400]	train-error:0.295455	test-error:0.255319
# [1401]	train-error:0.295455	test-error:0.276596
# [1402]	train-error:0.295455	test-error:0.255319
# [1403]	train-error:0.295455	test-error:0.255319
# [1404]	train-error:0.295455	test-error:0.255319
# [1405]	train-error:0.295455	test-error:0.255319
# [1406]	train-error:0.295455	test-error:0.255319
# [1407]	train-error:0.295455	test-error:0.276596
# [1408]	train-error:0.295455	test-error:0.255319
# [1409]	train-error:0.295455	test-error:0.255319
# [1410]	train-error:0.295455	test-error:0.276596
# [1411]	train-error:0.295455	test-error:0.255319
# [1412]	train-error:0.295455	test-error:0.255319
# [1413]	train-error:0.301136	test-error:0.276596
# [1414]	train-error:0.295455	test-error:0.255319
# [1415]	train-error:0.295455	test-error:0.255319
# [1416]	train-error:0.301136	test-error:0.276596
# [1417]	train-error:0.295455	test-error:0.276596
# [1418]	train-error:0.295455	test-error:0.276596
# [1419]	train-error:0.295455	test-error:0.255319
# [1420]	train-error:0.295455	test-error:0.276596
# [1421]	train-error:0.295455	test-error:0.255319
# [1422]	train-error:0.295455	test-error:0.276596
# [1423]	train-error:0.295455	test-error:0.255319
# [1424]	train-error:0.301136	test-error:0.255319
# [1425]	train-error:0.295455	test-error:0.255319
# [1426]	train-error:0.301136	test-error:0.255319
# [1427]	train-error:0.295455	test-error:0.255319
# [1428]	train-error:0.295455	test-error:0.276596
# [1429]	train-error:0.295455	test-error:0.255319
# [1430]	train-error:0.301136	test-error:0.255319
# [1431]	train-error:0.295455	test-error:0.255319
# [1432]	train-error:0.301136	test-error:0.276596
# [1433]	train-error:0.295455	test-error:0.255319
# [1434]	train-error:0.301136	test-error:0.276596
# [1435]	train-error:0.295455	test-error:0.255319
# [1436]	train-error:0.295455	test-error:0.255319
# [1437]	train-error:0.295455	test-error:0.255319
# [1438]	train-error:0.295455	test-error:0.255319
# [1439]	train-error:0.301136	test-error:0.255319
# [1440]	train-error:0.295455	test-error:0.255319
# [1441]	train-error:0.301136	test-error:0.276596
# [1442]	train-error:0.295455	test-error:0.255319
# [1443]	train-error:0.301136	test-error:0.276596
# [1444]	train-error:0.295455	test-error:0.255319
# [1445]	train-error:0.301136	test-error:0.276596
# [1446]	train-error:0.301136	test-error:0.276596
# [1447]	train-error:0.301136	test-error:0.276596
# [1448]	train-error:0.301136	test-error:0.276596
# [1449]	train-error:0.301136	test-error:0.276596
# [1450]	train-error:0.301136	test-error:0.255319
# [1451]	train-error:0.301136	test-error:0.276596
# [1452]	train-error:0.295455	test-error:0.255319
# [1453]	train-error:0.301136	test-error:0.276596
# [1454]	train-error:0.301136	test-error:0.255319
# [1455]	train-error:0.301136	test-error:0.255319
# [1456]	train-error:0.295455	test-error:0.255319
# [1457]	train-error:0.301136	test-error:0.255319
# [1458]	train-error:0.301136	test-error:0.255319
# [1459]	train-error:0.301136	test-error:0.255319
# [1460]	train-error:0.301136	test-error:0.255319
# [1461]	train-error:0.301136	test-error:0.255319
# [1462]	train-error:0.301136	test-error:0.276596
# [1463]	train-error:0.301136	test-error:0.255319
# [1464]	train-error:0.306818	test-error:0.276596
# [1465]	train-error:0.301136	test-error:0.255319
# [1466]	train-error:0.301136	test-error:0.276596
# [1467]	train-error:0.301136	test-error:0.276596
# [1468]	train-error:0.301136	test-error:0.255319
# [1469]	train-error:0.301136	test-error:0.255319
# [1470]	train-error:0.301136	test-error:0.255319
# [1471]	train-error:0.301136	test-error:0.276596
# [1472]	train-error:0.301136	test-error:0.255319
# [1473]	train-error:0.301136	test-error:0.276596
# [1474]	train-error:0.301136	test-error:0.255319
# [1475]	train-error:0.301136	test-error:0.276596
# [1476]	train-error:0.301136	test-error:0.276596
# [1477]	train-error:0.301136	test-error:0.276596
# [1478]	train-error:0.301136	test-error:0.276596
# [1479]	train-error:0.301136	test-error:0.276596
# [1480]	train-error:0.301136	test-error:0.276596
# [1481]	train-error:0.301136	test-error:0.276596
# [1482]	train-error:0.301136	test-error:0.276596
# [1483]	train-error:0.301136	test-error:0.276596
# [1484]	train-error:0.301136	test-error:0.276596
# [1485]	train-error:0.301136	test-error:0.276596
# [1486]	train-error:0.301136	test-error:0.276596
# [1487]	train-error:0.301136	test-error:0.276596
# [1488]	train-error:0.301136	test-error:0.276596
# [1489]	train-error:0.301136	test-error:0.276596
# [1490]	train-error:0.301136	test-error:0.276596
# [1491]	train-error:0.301136	test-error:0.276596
# [1492]	train-error:0.301136	test-error:0.276596
# [1493]	train-error:0.301136	test-error:0.276596
# [1494]	train-error:0.301136	test-error:0.276596
# [1495]	train-error:0.301136	test-error:0.255319
# [1496]	train-error:0.295455	test-error:0.276596
# [1497]	train-error:0.301136	test-error:0.255319
# [1498]	train-error:0.301136	test-error:0.276596
# [1499]	train-error:0.301136	test-error:0.255319
# [1500]	train-error:0.306818	test-error:0.276596
# [1501]	train-error:0.301136	test-error:0.276596
# [1502]	train-error:0.301136	test-error:0.276596
# [1503]	train-error:0.301136	test-error:0.276596
# [1504]	train-error:0.301136	test-error:0.276596
# [1505]	train-error:0.301136	test-error:0.276596
# [1506]	train-error:0.301136	test-error:0.276596
# [1507]	train-error:0.301136	test-error:0.276596
# [1508]	train-error:0.301136	test-error:0.276596
# [1509]	train-error:0.301136	test-error:0.276596
# [1510]	train-error:0.301136	test-error:0.276596
# [1511]	train-error:0.301136	test-error:0.276596
# [1512]	train-error:0.306818	test-error:0.276596
# [1513]	train-error:0.301136	test-error:0.276596
# [1514]	train-error:0.301136	test-error:0.276596
# [1515]	train-error:0.301136	test-error:0.276596
# [1516]	train-error:0.301136	test-error:0.276596
# [1517]	train-error:0.301136	test-error:0.276596
# [1518]	train-error:0.301136	test-error:0.276596
# [1519]	train-error:0.301136	test-error:0.276596
# [1520]	train-error:0.301136	test-error:0.276596
# [1521]	train-error:0.301136	test-error:0.276596
# [1522]	train-error:0.301136	test-error:0.276596
# [1523]	train-error:0.301136	test-error:0.276596
# [1524]	train-error:0.301136	test-error:0.276596
# [1525]	train-error:0.301136	test-error:0.276596
# [1526]	train-error:0.301136	test-error:0.276596
# [1527]	train-error:0.301136	test-error:0.276596
# [1528]	train-error:0.301136	test-error:0.276596
# [1529]	train-error:0.301136	test-error:0.276596
# [1530]	train-error:0.301136	test-error:0.276596
# [1531]	train-error:0.301136	test-error:0.276596
# [1532]	train-error:0.301136	test-error:0.276596
# [1533]	train-error:0.301136	test-error:0.276596
# [1534]	train-error:0.301136	test-error:0.276596
# [1535]	train-error:0.301136	test-error:0.276596
# [1536]	train-error:0.301136	test-error:0.255319
# [1537]	train-error:0.301136	test-error:0.276596
# [1538]	train-error:0.301136	test-error:0.276596
# [1539]	train-error:0.306818	test-error:0.276596
# [1540]	train-error:0.301136	test-error:0.276596
# [1541]	train-error:0.301136	test-error:0.276596
# [1542]	train-error:0.301136	test-error:0.276596
# [1543]	train-error:0.301136	test-error:0.276596
# [1544]	train-error:0.301136	test-error:0.276596
# [1545]	train-error:0.301136	test-error:0.276596
# [1546]	train-error:0.301136	test-error:0.276596
# [1547]	train-error:0.301136	test-error:0.276596
# [1548]	train-error:0.301136	test-error:0.276596
# [1549]	train-error:0.306818	test-error:0.276596
# [1550]	train-error:0.301136	test-error:0.276596
# [1551]	train-error:0.295455	test-error:0.276596
# [1552]	train-error:0.301136	test-error:0.276596
# [1553]	train-error:0.295455	test-error:0.276596
# [1554]	train-error:0.301136	test-error:0.276596
# [1555]	train-error:0.301136	test-error:0.276596
# [1556]	train-error:0.301136	test-error:0.276596
# [1557]	train-error:0.301136	test-error:0.276596
# [1558]	train-error:0.301136	test-error:0.276596
# [1559]	train-error:0.301136	test-error:0.276596
# [1560]	train-error:0.301136	test-error:0.276596
# [1561]	train-error:0.301136	test-error:0.276596
# [1562]	train-error:0.295455	test-error:0.276596
# [1563]	train-error:0.301136	test-error:0.276596
# [1564]	train-error:0.301136	test-error:0.276596
# [1565]	train-error:0.301136	test-error:0.276596
# [1566]	train-error:0.301136	test-error:0.276596
# [1567]	train-error:0.301136	test-error:0.276596
# [1568]	train-error:0.301136	test-error:0.276596
# [1569]	train-error:0.301136	test-error:0.276596
# [1570]	train-error:0.306818	test-error:0.276596
# [1571]	train-error:0.301136	test-error:0.276596
# [1572]	train-error:0.301136	test-error:0.276596
# [1573]	train-error:0.301136	test-error:0.276596
# [1574]	train-error:0.301136	test-error:0.276596
# [1575]	train-error:0.301136	test-error:0.276596
# [1576]	train-error:0.301136	test-error:0.276596
# [1577]	train-error:0.306818	test-error:0.276596
# [1578]	train-error:0.306818	test-error:0.276596
# [1579]	train-error:0.306818	test-error:0.276596
# [1580]	train-error:0.301136	test-error:0.276596
# [1581]	train-error:0.301136	test-error:0.276596
# [1582]	train-error:0.306818	test-error:0.276596
# [1583]	train-error:0.306818	test-error:0.255319
# [1584]	train-error:0.301136	test-error:0.276596
# [1585]	train-error:0.306818	test-error:0.276596
# [1586]	train-error:0.301136	test-error:0.276596
# [1587]	train-error:0.306818	test-error:0.276596
# [1588]	train-error:0.306818	test-error:0.276596
# [1589]	train-error:0.306818	test-error:0.276596
# [1590]	train-error:0.301136	test-error:0.276596
# [1591]	train-error:0.306818	test-error:0.276596
# [1592]	train-error:0.306818	test-error:0.276596
# [1593]	train-error:0.306818	test-error:0.276596
# [1594]	train-error:0.306818	test-error:0.276596
# [1595]	train-error:0.306818	test-error:0.276596
# [1596]	train-error:0.301136	test-error:0.276596
# [1597]	train-error:0.301136	test-error:0.276596
# [1598]	train-error:0.301136	test-error:0.276596
# [1599]	train-error:0.301136	test-error:0.276596

# %%
X_test = pred_games_df.drop(columns = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'week','result'])
y_pred = clf.predict_proba(X_test)
y_pred = y_pred[:,1]

display(y_pred,pred_games_df)
# Out:
# The Minnesota Vikings have a probability of 0.32 of beating the New Orleans Saints.
# The Tampa Bay Buccaneers have a probability of 0.83 of beating the Detroit Lions.
# The San Francisco 49ers have a probability of 0.4 of beating the Arizona Cardinals.
# The Miami Dolphins have a probability of 0.42 of beating the Las Vegas Raiders.
# The New York Giants have a probability of 0.18 of beating the Baltimore Ravens.
# The Indianapolis Colts have a probability of 0.27 of beating the Pittsburgh Steelers.
# The Cleveland Browns have a probability of 0.78 of beating the New York Jets.
# The Atlanta Falcons have a probability of 0.16 of beating the Kansas City Chiefs.
# The Chicago Bears have a probability of 0.75 of beating the Jacksonville Jaguars.
# The Cincinnati Bengals have a probability of 0.57 of beating the Houston Texans.
# The Carolina Panthers have a probability of 0.73 of beating the Washington Football Team.
# The Denver Broncos have a probability of 0.5 of beating the Los Angeles Chargers.
# The Los Angeles Rams have a probability of 0.45 of beating the Seattle Seahawks.
# The Philadelphia Eagles have a probability of 0.59 of beating the Dallas Cowboys.
# The Tennessee Titans have a probability of 0.28 of beating the Green Bay Packers.
# The Buffalo Bills have a probability of 0.78 of beating the New England Patriots.
